# %%
epochs, batch, lr = 100, 64, 1e-4
num_clients, in_channels, num_classes = 6, 1, 10
Dataset, Model, Prefix = 'Fashion', 'VGG_7', 'Train2'
Gdrive = '/content/drive/MyDrive/Colab Notebooks/SplitLearning3'
import torch; torch.cuda.get_device_properties(0)
# Out:
# _CudaDeviceProperties(name='Tesla T4', major=7, minor=5, total_memory=15109MB, multi_processor_count=40)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os; os.chdir(Gdrive)
# %run library/Dataset.ipynb
# %run library/Network.ipynb
# %run library/Training.ipynb
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting duy-book
#   Downloading duy_book-0.2.4-py3-none-any.whl (2.9 kB)
# Installing collected packages: duy-book
# Successfully installed duy-book-0.2.4

# %%
dataset, testset = loadDataset()

# %% [markdown]
# #Imbalance

# %%
clients = np.array([1, 3, 9, 19, 30, 38])
clients = ratio_split(dataset, clients / clients.sum())

# %%
old_indices, new_indices = [0,2,3,5], [1,4]
old_clients = [clients[i] for i in old_indices]
new_clients = [clients[i] for i in new_indices]

# %%
# private training with allcomers
network = train_splitnn(old_clients, (testset), 'private')
saveAccuracies(Gdrive, network.clients, 'ImB-All-1st')
saveAccuracies(Gdrive, train_private_all(network, new_clients, (testset)).clients, 'ImB-All-2nd')
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# Output()
# /content/drive/MyDrive/Colab Notebooks/SplitLearning3/data/Fashion-VGG_7-Train2-6-ImB-All-1st.acc
#   0%|          | 0/100 [00:00<?, ?it/s]
# Output()
# /content/drive/MyDrive/Colab Notebooks/SplitLearning3/data/Fashion-VGG_7-Train2-6-ImB-All-2nd.acc

# %%
# private training with newcomers
network = train_splitnn(old_clients, (testset), 'private')
saveAccuracies(Gdrive, network.clients, 'ImB-New-1st')
saveAccuracies(Gdrive, train_private_new(network, new_clients, (testset)).all_clients(), 'ImB-New-2nd')
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# Output()
# /content/drive/MyDrive/Colab Notebooks/SplitLearning3/data/Fashion-VGG_7-Train2-6-ImB-New-1st.acc
#   0%|          | 0/100 [00:00<?, ?it/s]
# Output()
# /content/drive/MyDrive/Colab Notebooks/SplitLearning3/data/Fashion-VGG_7-Train2-6-ImB-New-2nd.acc

# %%
caches = [8 for i in range(len(old_clients))]
# private training with caching
network = train_splitnn(old_clients, (testset), 'private', caches=caches)
saveAccuracies(Gdrive, network.clients, 'ImB-Cac-1st')
saveAccuracies(Gdrive, train_private_new(network, new_clients, (testset), caches=caches).all_clients(), 'ImB-Cac-2nd')
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# Output()
# /content/drive/MyDrive/Colab Notebooks/SplitLearning3/data/Fashion-VGG_7-Train2-6-ImB-Cac-1st.acc
#   0%|          | 0/100 [00:00<?, ?it/s]
# Output()
# /content/drive/MyDrive/Colab Notebooks/SplitLearning3/data/Fashion-VGG_7-Train2-6-ImB-Cac-2nd.acc

# %%
caches = [8 for i in range(len(old_clients))]
# private training with caching
network = train_splitnn(old_clients, (testset), 'private')
saveAccuracies(Gdrive, network.clients, 'ImB-Cac-1st')
saveAccuracies(Gdrive, train_private_new(network, new_clients, (testset), caches=caches).all_clients(), 'ImB-Cac-2nd')
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# Output()
# /content/drive/MyDrive/Colab Notebooks/SplitLearning3/data/Fashion-VGG_7-Train2-6-ImB-Cac-1st.acc
#   0%|          | 0/100 [00:00<?, ?it/s]
# Output()
# /content/drive/MyDrive/Colab Notebooks/SplitLearning3/data/Fashion-VGG_7-Train2-6-ImB-Cac-2nd.acc

# %%
caches = [16 for i in range(len(old_clients))]
# private training with caching
network = train_splitnn(old_clients, (testset), 'private')
saveAccuracies(Gdrive, network.clients, 'ImB-Cac-1st')
saveAccuracies(Gdrive, train_private_new(network, new_clients, (testset), caches=caches).all_clients(), 'ImB-Cac-2nd')
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# Output()
# /content/drive/MyDrive/Colab Notebooks/SplitLearning3/data/Fashion-VGG_7-Train2-6-ImB-Cac-1st.acc
#   0%|          | 0/100 [00:00<?, ?it/s]
# Output()
# /content/drive/MyDrive/Colab Notebooks/SplitLearning3/data/Fashion-VGG_7-Train2-6-ImB-Cac-2nd.acc
