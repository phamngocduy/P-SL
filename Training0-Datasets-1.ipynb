# %%
epochs, batch, lr = 100, 64, 1e-4
num_clients, in_channels, num_classes = 10, 1, 10
Dataset, Model, Prefix = 'MNIST', 'CNN_3', 'Train0'
Gdrive = '/content/drive/MyDrive/Colab Notebooks/SplitLearning3'
import torch; torch.cuda.get_device_properties(0)
# Out:
# _CudaDeviceProperties(name='Tesla T4', major=7, minor=5, total_memory=15109MB, multi_processor_count=40)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os; os.chdir(Gdrive)
# %run library/Dataset.ipynb
# %run library/Network.ipynb
# %run library/Training.ipynb
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
dataset, testset = loadDataset('MNIST')
max(train_separate([dataset], (testset, 1, 10))[0].clients[0].accuracy)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# Output()
# 0.9906

# %%
dataset, testset = loadDataset('Fashion')
max(train_separate([dataset], (testset, 1, 10), model='VGG_7')[0].clients[0].accuracy)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# Output()
# 0.9375

# %%
dataset, testset = loadDataset('CIFAR')
max(train_separate([dataset], (testset, 3, 10), model='VGG_11')[0].clients[0].accuracy)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
#   0%|          | 0/100 [00:00<?, ?it/s]
# Output()
# 0.8604
