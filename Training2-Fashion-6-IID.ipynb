# %%
epochs, batch, lr = 100, 64, 1e-4
num_clients, in_channels, num_classes = 6, 1, 10
Dataset, Model, Prefix = 'Fashion', 'VGG_7', 'Train2'
Gdrive = '/content/drive/MyDrive/Colab Notebooks/SplitLearning3'
import torch; torch.cuda.get_device_properties(0)
# Out:
# _CudaDeviceProperties(name='Tesla T4', major=7, minor=5, total_memory=15109MB, multi_processor_count=40)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os; os.chdir(Gdrive)
# %run library/Dataset.ipynb
# %run library/Network.ipynb
# %run library/Training.ipynb
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: duy-book in /usr/local/lib/python3.7/dist-packages (0.2.4)

# %%
dataset, testset = loadDataset()

# %% [markdown]
# #Balance

# %%
clients = torch.ones((num_clients,))
clients = ratio_split(dataset, clients / clients.sum())

# %%
old_indices, new_indices = [0,2,3,5], [1,4]
old_clients = [clients[i] for i in old_indices]
new_clients = [clients[i] for i in new_indices]

# %%
# private training with allcomers
network = train_splitnn(old_clients, (testset), 'private')
saveAccuracies(Gdrive, network.clients, 'IID-All-1st')
saveAccuracies(Gdrive, train_private_all(network, new_clients, (testset)).clients, 'IID-All-2nd')
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# Output()
# /content/drive/MyDrive/Colab Notebooks/SplitLearning3/data/Fashion-VGG_7-Train2-6-IID-All-1st.acc
#   0%|          | 0/100 [00:00<?, ?it/s]
# Output()
# /content/drive/MyDrive/Colab Notebooks/SplitLearning3/data/Fashion-VGG_7-Train2-6-IID-All-2nd.acc

# %%
# private training with newcomers
network = train_splitnn(old_clients, (testset), 'private')
saveAccuracies(Gdrive, network.clients, 'IID-New-1st')
saveAccuracies(Gdrive, train_private_new(network, new_clients, (testset)).all_clients(), 'IID-New-2nd')
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# Output()
# /content/drive/MyDrive/Colab Notebooks/SplitLearning3/data/Fashion-VGG_7-Train2-6-IID-New-1st.acc
#   0%|          | 0/100 [00:00<?, ?it/s]
# Output()
# /content/drive/MyDrive/Colab Notebooks/SplitLearning3/data/Fashion-VGG_7-Train2-6-IID-New-2nd.acc

# %%
caches = [8 for i in range(len(old_clients))]
# private training with caching
network = train_splitnn(old_clients, (testset), 'private', caches=caches)
saveAccuracies(Gdrive, network.clients, 'IID-Cac-1st')
saveAccuracies(Gdrive, train_private_new(network, new_clients, (testset), caches=caches).all_clients(), 'IID-Cac-2nd')
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# Output()
# /content/drive/MyDrive/Colab Notebooks/SplitLearning3/data/Fashion-VGG_7-Train2-6-IID-Cac-1st.acc
#   0%|          | 0/100 [00:00<?, ?it/s]
# Output()
# /content/drive/MyDrive/Colab Notebooks/SplitLearning3/data/Fashion-VGG_7-Train2-6-IID-Cac-2nd.acc

# %%
caches = [8 for i in range(len(old_clients))]
# private training with caching
network = train_splitnn(old_clients, (testset), 'private')
saveAccuracies(Gdrive, network.clients, 'IID-Cac-1st')
saveAccuracies(Gdrive, train_private_new(network, new_clients, (testset), caches=caches).all_clients(), 'IID-Cac-2nd')
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# Output()
# /content/drive/MyDrive/Colab Notebooks/SplitLearning3/data/Fashion-VGG_7-Train2-6-IID-Cac-1st.acc
#   0%|          | 0/100 [00:00<?, ?it/s]
# Output()
# /content/drive/MyDrive/Colab Notebooks/SplitLearning3/data/Fashion-VGG_7-Train2-6-IID-Cac-2nd.acc

# %%
caches = [16 for i in range(len(old_clients))]
# private training with caching
network = train_splitnn(old_clients, (testset), 'private')
saveAccuracies(Gdrive, network.clients, 'IID-Cac-1st')
saveAccuracies(Gdrive, train_private_new(network, new_clients, (testset), caches=caches).all_clients(), 'IID-Cac-2nd')
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# Output()
# /content/drive/MyDrive/Colab Notebooks/SplitLearning3/data/Fashion-VGG_7-Train2-6-IID-Cac-1st.acc
#   0%|          | 0/100 [00:00<?, ?it/s]
# Output()
# /content/drive/MyDrive/Colab Notebooks/SplitLearning3/data/Fashion-VGG_7-Train2-6-IID-Cac-2nd.acc
