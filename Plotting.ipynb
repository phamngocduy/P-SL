# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import torch, os, numpy as np
import matplotlib.pyplot as plt
os.chdir('/content/drive/MyDrive/ColabNotebooks/SplitLearning3/data')

# %%
acc = torch.load('CIFAR-VGG_11-Train1-6-Non-Prv-Rnd.acc')
for c in acc: plt.plot(c, label=c[-1]); plt.legend()
print(np.array(acc)[:,-1].mean())
# Out:
# 0.45483333333333337

# %%
acc = torch.load('CIFAR-VGG_11-Train1-6-Non-Seq-Rnd.acc')
for c in acc: plt.plot(c, label=c[-1]); plt.legend()
print(np.array(acc)[:,-1].mean())
# Out:
# 0.5263333333333333

# %%
acc = torch.load('CIFAR-VGG_11-Train1-6-Non-Fed-Rnd.acc')
for c in acc: plt.plot(c, label=c[-1]); plt.legend()
print(np.array(acc)[:,-1].mean())
# Out:
# 0.5378

# %%
acc = torch.load('CIFAR-VGG_11-Train1-6-100-Prv-Cac.acc')
for c in acc: plt.plot(c, label=c[-1]); plt.legend()
print(np.array(acc)[:,-1].mean())
# Out:
# 0.4719166666666667

# %%
acc = torch.load('CIFAR-VGG_11-Train1-6-Non-Seq-Cac.acc')
for c in acc: plt.plot(c, label=c[-1]); plt.legend()
print(np.array(acc)[:,-1].mean())
# Out:
# 0.8314666666666666

# %%
acc = torch.load('CIFAR-VGG_11-Train1-6-Non-Fed-Cac.acc')
for c in acc: plt.plot(c, label=c[-1]); plt.legend()
print(np.array(acc)[:,-1].mean())
# Out:
# 0.7998

# %%
acc = torch.load('Fashion-VGG_7-Train1-6-Non-Prv-Rnd.acc')
for c in acc: plt.plot(c, label=c[-1]); plt.legend()
print(np.array(acc)[:,-1].mean())
# Out:
# 0.5457833333333334

# %%
acc = torch.load('Fashion-VGG_7-Train1-6-Non-Seq-Rnd.acc')
for c in acc: plt.plot(c, label=c[-1]); plt.legend()
print(np.array(acc)[:,-1].mean())
# Out:
# 0.54045

# %%
acc = torch.load('Fashion-VGG_7-Train1-6-Non-Fed-Rnd.acc')
for c in acc: plt.plot(c, label=c[-1]); plt.legend()
print(np.array(acc)[:,-1].mean())
# Out:
# 0.582

# %%
acc = torch.load('Fashion-VGG_7-Train1-6-100-Prv-Cac.acc')
for c in acc: plt.plot(c, label=c[-1]); plt.legend()
print(np.array(acc)[:,-1].mean())
# Out:
# 0.5607

# %%
acc = torch.load('Fashion-VGG_7-Train1-6-Non-Seq-Cac.acc')
for c in acc: plt.plot(c, label=c[-1]); plt.legend()
print(np.array(acc)[:,-1].mean())
# Out:
# 0.8912666666666667

# %%
acc = torch.load('Fashion-VGG_7-Train1-6-Non-Fed-Cac.acc')
for c in acc: plt.plot(c, label=c[-1]); plt.legend()
print(np.array(acc)[:,-1].mean())
# Out:
# 0.9124

# %% [markdown]
# #DP

# %%
from scipy.ndimage.filters import gaussian_filter1d
# Out:
# <ipython-input-7-4acf63f28833>:1: DeprecationWarning: Please use `gaussian_filter1d` from the `scipy.ndimage` namespace, the `scipy.ndimage.filters` namespace is deprecated.
#   from scipy.ndimage.filters import gaussian_filter1d

# %%
propose = [[91.52, 91.89, 91.91, 91.78, 91.78, 91.82], [98.41, 49.96, 50.76, 52.25, 52.83, 50.25]]
propose = np.array(propose) / 100
for i in range(6):
  plt.scatter(1-propose[1,i], propose[0,i]*100, marker='o', s=45)
epsilon = [[82.41, 82.53, 82.42, 82.45, 82.97, 82.73], [25.71, 30.91, 28.72, 26.67, 26.43, 21.82],
           [85.76, 85.94, 86.13, 86.02, 86.04, 85.89], [38.11, 46.85, 36.47, 30.52, 42.29, 40.05],
           [88.72, 88.18, 88.53, 88.36, 88.13, 88.55], [42.53, 56.83, 43.41, 49.89, 60.62, 55.38],
           [90.29, 90.09, 89.84, 90.38, 89.96, 90.45], [67.26, 63.03, 58.54, 56.71, 64.58, 59.52],
           [90.97, 91.04, 90.94, 91.01, 90.92, 90.81], [68.62, 72.16, 73.41, 71.19, 68.71, 75.15],
           [92.18, 92.02, 92.23, 92.21, 92.12, 92.12], [80.61, 78.77, 77.41, 77.17, 82.14, 78.11],
           [92.76, 92.51, 92.59, 92.72, 92.69, 92.92], [82.92, 83.33, 79.21, 79.33, 80.04, 83.56],
           #[92.58, 92.56, 92.66, 92.42, 92.62, 92.56], [87.74, 86.17, 86.39, 85.55, 86.38, 85.91],
           #[92.31, 92.41, 92.51, 92.33, 92.31, 92.27], [81.24, 83.16, 79.45, 83.92, 83.64, 79.69],
           #[92.36, 92.61, 92.41, 92.45, 92.31, 92.46], [86.36, 87.26, 88.05, 88.59, 88.17, 89.61],
           #[92.89, 92.91, 92.83, 93.03, 92.85, 92.76], [88.93, 87.91, 87.95, 86.95, 88.31, 87.96],
           [93.11, 93.11, 93.13, 92.98, 93.19, 93.11], [86.65, 88.22, 86.62, 86.97, 86.47, 87.49]]
epsilon = np.array(epsilon) / 100
for i in range(6):
  sm = .9
  plt.plot(gaussian_filter1d(1-epsilon[1:-2:2,i],sm), gaussian_filter1d(epsilon[0:-2:2,i]*100,sm))
#plt.gca().set_aspect('equal', adjustable='box')
plt.xlim(.2, .7), plt.ylim(83, 93)
plt.xlabel('Privacy (1–SSIM)'), plt.ylabel('Accuracy (%)')
# Out:
# (Text(0.5, 0, 'Privacy (1–SSIM)'), Text(0, 0.5, 'Accuracy (%)'))

# %%
DISCO = [[86.62, 86.74, 86.81, 86.68, 86.66, 86.70], [.32, .32, .32, .24, .32, .23], [.60, .60, .59, .56, .60, .55], #.6
         [89.37, 89.40, 89.33, 89.30, 89.37, 89.26], [.41, .42, .42, .42, .41, .41], [.77, .77, .77, .76, .77, .77], #.5
         #[90.19, 90.11, 90.00, 89.93, 90.09, 90.16], [.55, .55, .55, .55, .55, .55], [.80, .80, .79, .79, .80, .80], #.4
         #[91.56, 91.60, 91.62, 91.48, 91.52, 91.61], [.43, .43, .43, .43, .43, .43], [.80, .80, .80, .80, .80, .80], #.3
         [92.29, 92.22, 92.29, 92.30, 92.24, 92.22], [.60, .60, .60, .60, .60, .60], [.88, .88, .88, .88, .88, .88], #.2
         #[91.49, 91.55, 91.40, 91.45, 91.41, 91.39], [.81, .80, .80, .81, .81, .81], [.90, .89, .90, .90, .90, .90], #.1
         [93.14, 93.21, 93.16, 93.20, 93.20, 93.17], [.96, .96, .96, .96, .96, .94], [.98, .98, .98, .98, .98, .98]]

# %%
RESSFL = [[8990, 9114, 8688, 9136, 9229, 9398, 9228, 8508, 9002, 8692],
          [8917, 8927, 8927, 8930, 9042, 9069, 9172, 9218, 9257, 9278]]

# %%
fig = plt.figure()
axs = fig.add_subplot(111)
axs.scatter(propose[1,1:].mean(), sum([92.5,92.4,92.6,92.6,92.6])/5, s=45)
axs.scatter(propose[1,1:].mean(), sum([92.5,92.4,92.6,92.6,92.6])/5, s=200, label='P–SL')
acc = np.array([epsilon[i] for i in range(0, len(epsilon), 2)])
sim = np.array([epsilon[i] for i in range(1, len(epsilon), 2)])
axs.plot(1-sim.mean(1), acc.mean(1)*100, label='DP')

acc = np.array([DISCO[i] for i in range(0, len(DISCO), 3)])
sim = np.array([DISCO[i] for i in range(1, len(DISCO), 3)])
axs.plot(1-sim.mean(1), acc.mean(1))
axs.plot(1-sim.mean(1), acc.mean(1), label='DISCO')

acc, sim = np.array(RESSFL[1]), np.array(RESSFL[0])
axs.scatter(1-sim.mean()/10000, acc.mean()/100, s=45)
axs.scatter(1-sim.mean()/10000, acc.mean()/100, s=45)
axs.scatter(1-sim.mean()/10000, acc.mean()/100, s=200, label='ResSFL')

plt.xlabel('Privacy (1–SSIM)'), plt.ylabel('Accuracy (%)')
plt.grid(), plt.legend()
plt.rcParams.update({'font.size': 16})

# %% [markdown]
# #6 Clients

# %%
num_clients = 6

# %%
cifar_mul = [acc[-1]*100 for acc in torch.load('CIFAR-VGG_11-Train1-6-IID-Non.acc')]
cifar_prv = [acc[-1]*100 for acc in torch.load('CIFAR-VGG_11-Train1-6-IID-Prv.acc')]
bar = 0.4
wis = np.arange(num_clients)
prv = [x + bar for x in wis]
plt.scatter(wis, cifar_mul)
plt.plot(cifar_mul, '--', label='mSL')
plt.scatter(wis, cifar_prv)
plt.plot(cifar_prv, label='P-SL')
#plt.xlabel('Client index')
plt.ylabel('Accuracy')
handles, labels = plt.gca().get_legend_handles_labels()
plt.legend(loc='lower right')
#plt.title('Learning performance under balanced CIFAR10')
plt.xticks([x + bar/2 for x in wis], [f'C{i+1}' for i in range(6)])
plt.ylim(0, 90)
plt.rcParams.update({'font.size': 18})

# %%
cifar_mul = [acc[-1]*100 for acc in torch.load('CIFAR-VGG_11-Train1-6-ImB-Non.acc')]
cifar_prv = [acc[-1]*100 for acc in torch.load('CIFAR-VGG_11-Train1-6-ImB-Prv.acc')]
bar = 0.4
wis = np.arange(num_clients)
prv = [x + bar for x in wis]
plt.scatter(wis, cifar_mul)
plt.plot(cifar_mul, '--', label='mSL')
plt.scatter(wis, cifar_prv)
plt.plot(cifar_prv, label='P-SL')
#plt.xlabel('Client index')
plt.ylabel('Accuracy')
handles, labels = plt.gca().get_legend_handles_labels()
plt.legend(loc='lower right')
#plt.title('Learning performance under imbalanced CIFAR10')
plt.xticks([x + bar/2 for x in wis], [f'C{i+1}' for i in range(6)])
plt.ylim(0, 90)
plt.rcParams.update({'font.size': 18})

# %%
cifar_all_1st = [acc[-1]*100 for acc in torch.load('CIFAR-VGG_11-Train2-6-ImB-All-1st.acc')]
cifar_all_1st.insert(1, 0), cifar_all_1st.insert(4, 0)
cifar_all_2nd = [acc[-1]*100 for acc in torch.load('CIFAR-VGG_11-Train2-6-ImB-All-2nd.acc')]
c_1, c_4 = cifar_all_2nd[4], cifar_all_2nd[5]
cifar_all_2nd = cifar_all_2nd[:4]
cifar_all_2nd.insert(1, c_1), cifar_all_2nd.insert(4, c_4)
cifar_new_2nd = [acc[-1]*100 for acc in torch.load('CIFAR-VGG_11-Train2-6-ImB-New-2nd.acc')]
c_1, c_4 = cifar_new_2nd[4], cifar_new_2nd[5]
cifar_new_2nd = cifar_new_2nd[:4]
cifar_new_2nd.insert(1, c_1), cifar_new_2nd.insert(4, c_4)
bar = 0.3
prv = np.arange(len(cifar_all_1st))
all = [x + bar for x in prv]
new = [x + bar for x in all]
plt.bar(prv, cifar_all_1st, bar, label='1st train (4 clients)')
plt.plot(cifar_all_2nd, '--')
plt.plot(cifar_all_2nd, '--', label='2nd train (6 clients)')
plt.scatter(prv, cifar_all_2nd)
plt.plot(cifar_new_2nd, label='2nd train (2 clients)')
plt.scatter(prv, cifar_new_2nd)
#plt.xlabel('Client index')
plt.ylabel('Accuracy')
handles, labels = plt.gca().get_legend_handles_labels()
order = [2,0,1]
plt.legend([handles[idx] for idx in order],[labels[idx] for idx in order], loc='lower right')
#plt.title('Learning performance under imbalanced CIFAR10')
plt.xticks([x for x in prv], [f'C{i+1}' for i in range(6)])
plt.ylim(0, 90)
plt.rcParams.update({'font.size': 18})

# %%
cifar_all_1st = [acc[-1]*100 for acc in torch.load('CIFAR-VGG_11-Train2-6-IID-New-1st.acc')]
cifar_all_1st.insert(1, 0), cifar_all_1st.insert(4, 0)
cifar_all_2nd = [acc[-1]*100 for acc in torch.load('CIFAR-VGG_11-Train2-6-IID-All-2nd.acc')]
c_1, c_4 = cifar_all_2nd[4], cifar_all_2nd[5]
cifar_all_2nd = cifar_all_2nd[:4]
cifar_all_2nd.insert(1, c_1), cifar_all_2nd.insert(4, c_4)
cifar_new_2nd = [acc[-1]*100 for acc in torch.load('CIFAR-VGG_11-Train2-6-IID-New-2nd.acc')]
c_1, c_4 = cifar_new_2nd[4], cifar_new_2nd[5]
cifar_new_2nd = cifar_new_2nd[:4]
cifar_new_2nd.insert(1, c_1), cifar_new_2nd.insert(4, c_4)
bar = 0.3
prv = np.arange(len(cifar_all_1st))
all = [x + bar for x in prv]
new = [x + bar for x in all]
plt.bar(prv, cifar_all_1st, bar, label='1st train (4 clients)')
plt.plot(cifar_all_2nd, '--')
plt.plot(cifar_all_2nd, '--', label='2nd train (6 clients)')
plt.scatter(prv, cifar_all_2nd)
plt.plot(cifar_new_2nd, label='2nd train (2 clients)')
plt.scatter(prv, cifar_new_2nd)
#plt.xlabel('Client index')
plt.ylabel('Accuracy')
handles, labels = plt.gca().get_legend_handles_labels()
order = [2,0,1]
plt.legend([handles[idx] for idx in order],[labels[idx] for idx in order], loc='lower right')
#plt.title('Learning performance under balanced CIFAR10')
plt.xticks([x for x in prv], [f'C{i+1}' for i in range(6)])
plt.ylim(0, 90)
plt.rcParams.update({'font.size': 18})

# %%
fashion_new = [[a*100 for a in acc] for acc in torch.load('Fashion-VGG_7-Train2-6-IID-New-2nd.acc')]
'''
fashion_new.insert(1, []), fashion_new.insert(4, [])
for i, acc in enumerate(fashion_new[:-2]):
  if (len(acc) == 0): continue
  plt.plot(acc, label='C{}: {:.1%}'.format(i+1, acc[-1]/100))
plt.plot(fashion_new[-2], label='C2: {:.1%}(new)'.format(fashion_new[-2][-1]/100))
plt.plot(fashion_new[-1], label='C5: {:.1%}(new)'.format(fashion_new[-1][-1]/100))
'''
for i, acc in enumerate(fashion_new):
  plt.plot(acc, label='C{}: {:.1%}{}'.format(i+1, acc[-1]/100, ' (new)' if i==1 or i==4 else ''))
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
plt.title('Performance under balanced Fashion')
plt.ylim(84, 93)
plt.rcParams.update({'font.size': 15})

# %%
fashion_new = [[a*100 for a in acc] for acc in torch.load('Fashion-VGG_7-Train2-6-IID-Cac-2nd.acc')]
for i, acc in enumerate(fashion_new):
  plt.plot(acc, label='C{}: {:.1%}{}'.format(i+1, acc[-1]/100, ' (new)' if i==1 or i==4 else ''))
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
plt.title('Performance under balanced Fashion')
plt.ylim(84, 93)
plt.rcParams.update({'font.size': 15})

# %%
fashion_new = [[a*100 for a in acc] for acc in torch.load('Fashion-VGG_7-Train2-6-ImB-New-2nd.acc')]
for i, acc in enumerate(fashion_new):
  plt.plot(acc, label='C{}: {:.1%}{}'.format(i+1, acc[-1]/100, ' (new)' if i==1 or i==4 else ''))
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
plt.title('Performance under imbalanced Fashion')
plt.ylim(64, 93)
plt.rcParams.update({'font.size': 15})

# %%
fashion_new = [[a*100 for a in acc] for acc in torch.load('Fashion-VGG_7-Train2-6-ImB-Cac-2nd.acc')]
for i, acc in enumerate(fashion_new):
  plt.plot(acc, label='C{}: {:.1%}{}'.format(i+1, acc[-1]/100, ' (new)' if i==1 or i==4 else ''))
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
plt.title('Performance under imbalanced Fashion')
plt.ylim(64, 93)
plt.rcParams.update({'font.size': 15})

# %%
fashion_new = [[a*100 for a in acc] for acc in torch.load('CIFAR-VGG_11-Train2-6-IID-New-2nd.acc')]
for i, acc in enumerate(fashion_new):
  plt.plot(acc, label='C{}: {:.1%}{}'.format(i+1, acc[-1]/100, ' (new)' if i==1 or i==4 else ''))
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
plt.title('Performance under balanced CIFAR10')
plt.ylim(45, 82)
plt.rcParams.update({'font.size': 15})

# %%
fashion_new = [[a*100 for a in acc] for acc in torch.load('CIFAR-VGG_11-Train2-6-IID-Cac-2nd.acc')]
for i, acc in enumerate(fashion_new):
  plt.plot(acc, label='C{}: {:.1%}{}'.format(i+1, acc[-1]/100, ' (new)' if i==1 or i==4 else ''))
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
plt.title('Performance under balanced CIFAR10')
plt.ylim(45, 82)
plt.rcParams.update({'font.size': 15})

# %%
fashion_new = [[a*100 for a in acc] for acc in torch.load('CIFAR-VGG_11-Train2-6-ImB-New-2nd.acc')]
for i, acc in enumerate(fashion_new):
  plt.plot(acc, label='C{}: {:.1%}{}'.format(i+1, acc[-1]/100, ' (new)' if i==1 or i==4 else ''))
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
plt.title('Performance under imbalanced CIFAR10')
plt.ylim(25, 82)
plt.rcParams.update({'font.size': 15})

# %%
fashion_new = [[a*100 for a in acc] for acc in torch.load('CIFAR-VGG_11-Train2-6-ImB-Cac-2nd.acc')]
for i, acc in enumerate(fashion_new):
  plt.plot(acc, label='C{}: {:.1%}{}'.format(i+1, acc[-1]/100, ' (new)' if i==1 or i==4 else ''))
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
plt.title('Performance under imbalanced CIFAR10')
plt.ylim(25, 82)
plt.rcParams.update({'font.size': 15})

# %%
cifar_ran = [acc for acc in torch.load('CIFAR-VGG_11-Random-6-ImB-Prv-Rnd.acc')]
for i, acc in enumerate(cifar_ran):
  plt.plot(acc, label='C{}:{:.1%}'.format(i+1, acc[-1]))
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
#plt.title('Learning performance under imbalanced CIFAR10')
#plt.ylim(0.2, .95)
plt.rcParams.update({'font.size': 16})

# %%
cifar_ran = [acc for acc in torch.load('CIFAR-VGG_11-Random-6-ImB-Prv-Rnd-Cac.acc')]
for i, acc in enumerate(cifar_ran):
  plt.plot(acc, label='C{}:{:.1%}'.format(i+1, acc[-1]))
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
#plt.title('Learning performance under imbalanced CIFAR10')
#plt.ylim(0.2, .95)
plt.rcParams.update({'font.size': 16})

# %% [markdown]
# #Non-IID

# %%
fashion_prv = [acc for acc in torch.load('Fashion-VGG_7-Train1-6-Non-Prv.acc')]
fashion_seq = [acc for acc in torch.load('Fashion-VGG_7-Train1-6-Non-Seq-Rnd.acc')]
fashion_fed = [acc for acc in torch.load('Fashion-VGG_7-Train1-6-Non-Fed-Rnd.acc')]
for acc in fashion_prv: plt.plot(acc)
plt.plot(fashion_seq[-1])
plt.plot(fashion_fed[-1])

# %% [markdown]
# #10 Clients

# %%
clients = [i for i in range(1, 11)]

# %%
fashion_wis = [acc[-1] for acc in torch.load('Fashion-VGG_7-Train1-WiS.acc')]
fashion_prv = [acc[-1] for acc in torch.load('Fashion-VGG_7-Train1-Prv.acc')]
bar = 0.4
wis = np.arange(len(fashion_wis))
prv = [x + bar for x in wis]
plt.bar(wis, fashion_wis, bar, label='10SL')
plt.bar(prv, fashion_prv, bar, label='P-SL')
plt.xlabel('Client Index')
plt.ylabel('Learning Accuracy')
plt.legend(loc='upper left')
plt.title('Learning performance on Fashion dataset')
plt.xticks([x + bar/2 for x in wis], [f'C{i+1}' for i in range(10)])
plt.ylim(.75, .95)
# Out:
# (0.75, 0.95)

# %%
fashion_wis = [acc[-1]*100 for acc in torch.load('Fashion-VGG_7-Train1-IID-WiS.acc')]
fashion_prv = [acc[-1]*100 for acc in torch.load('Fashion-VGG_7-Train1-IID-Prv.acc')]
fashion_shr = [acc[-1]*100 for acc in torch.load('Fashion-VGG_7-Train1-IID-Shr.acc')]
fashion_avg = [acc[-1]*100 for acc in torch.load('Fashion-VGG_7-Train1-IID-Avg.acc')]
wis = np.arange(len(fashion_wis))
plt.scatter(wis, fashion_wis)
plt.plot(fashion_wis, label='nSL')
plt.scatter(wis, fashion_prv)
plt.plot(fashion_prv, label='PSL')
plt.xlabel('Client Index')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
plt.title('Learning performance under balanced Fashion')
plt.xticks([x + bar/2 for x in wis], [f'C{i+1}' for i in range(10)])
plt.ylim(70, 95)
# Out:
# (70.0, 95.0)

# %%
cifar_wis = [acc[-1]*100 for acc in torch.load('CIFAR-VGG_11-Train1-IID-WiS.acc')]
cifar_prv = [acc[-1]*100 for acc in torch.load('CIFAR-VGG_11-Train1-IID-Prv.acc')]
cifar_shr = [acc[-1]*100 for acc in torch.load('CIFAR-VGG_11-Train1-IID-Shr.acc')]
cifar_avg = [acc[-1]*100 for acc in torch.load('CIFAR-VGG_11-Train1-IID-Avg.acc')]
#plt.plot([acc-.7 for acc in cifar_shr], label='oSL')
#plt.plot([cifar_avg[-1] for _ in cifar_avg], label='SFL')
bar = 0.4
wis = np.arange(len(fashion_wis))
prv = [x + bar for x in wis]
#plt.bar(wis, cifar_wis, bar, label='nSL')
plt.scatter(wis, cifar_wis)
plt.plot(cifar_wis, label='nSL')
#plt.bar(prv, cifar_prv, bar, label='PSL')
plt.scatter(wis, cifar_prv)
plt.plot(cifar_prv, label='PSL')
plt.xlabel('Client Index')
plt.ylabel('Accuracy')
handles, labels = plt.gca().get_legend_handles_labels()
#order = [2,3,0,1]
#plt.legend([handles[i] for i in order],[labels[i] for i in order], loc='lower right')
plt.legend(loc='lower right')
plt.title('Learning performance under balanced CIFAR10')
plt.xticks([x + bar/2 for x in wis], [f'C{i+1}' for i in range(10)])
plt.ylim(20, 90)
# Out:
# (20.0, 90.0)

# %%
cifar_wis = [acc[-1]*100 for acc in torch.load('CIFAR-VGG_11-Train1-WiS.acc')]
cifar_prv = [acc[-1]*100 for acc in torch.load('CIFAR-VGG_11-Train1-Prv.acc')]
cifar_shr = [acc[-1]*100 for acc in torch.load('CIFAR-VGG_11-Train1-Shr.acc')]
cifar_avg = [acc[-1]*100 for acc in torch.load('CIFAR-VGG_11-Train1-Avg.acc')]
#plt.plot([acc for acc in cifar_shr], label='oSL')
#plt.plot([cifar_avg[-1] for _ in cifar_shr], label='SFL')
bar = 0.4
wis = np.arange(len(fashion_wis))
prv = [x + bar for x in wis]
#plt.bar(wis, cifar_wis, bar, label='nSL')
plt.scatter(wis, cifar_wis)
plt.plot(cifar_wis, label='nSL')
#plt.bar(prv, cifar_prv, bar, label='PSL')
plt.scatter(wis, cifar_prv)
plt.plot(cifar_prv, label='PSL')
plt.xlabel('Client Index')
plt.ylabel('Accuracy')
handles, labels = plt.gca().get_legend_handles_labels()
#order = [2,3,0,1]
#plt.legend([handles[i] for i in order],[labels[i] for i in order], loc='lower right')
plt.legend(loc='lower right')
plt.title('Learning performance under imbalanced CIFAR10')
plt.xticks([x + bar/2 for x in wis], [f'C{i+1}' for i in range(10)])
plt.ylim(20, 90)
# Out:
# (20.0, 90.0)

# %%
fashion_all = [acc[-1] for acc in torch.load('Fashion-VGG_7-Train2-All.acc')]
fashion_all.insert(0, 0), fashion_all.insert(4, 0)
fashion_all_15 = [acc[-1] for acc in torch.load('Fashion-VGG_7-Train2-All-15.acc')]
c_0, c_4 = fashion_all_15[8], fashion_all_15[9]
fashion_all_15 = fashion_all_15[:8]
fashion_all_15.insert(0, c_0), fashion_all_15.insert(4, c_4)
fashion_new_15 = [acc[-1] for acc in torch.load('Fashion-VGG_7-Train2-New-15.acc')]
c_0, c_4 = fashion_new_15[8], fashion_new_15[9]
fashion_new_15 = fashion_new_15[:8]
fashion_new_15.insert(0, c_0), fashion_new_15.insert(4, c_4)
bar = 0.3
prv = np.arange(len(fashion_all))
all = [x + bar for x in prv]
new = [x + bar for x in all]
plt.bar(prv, fashion_all, bar, label='1st train (w/t C1,C5)')
plt.bar(all, fashion_all_15, bar, label='2nd train (w C1-C10)')
plt.bar(new, fashion_new_15, bar, label='2nd train (w C1,C5)')
plt.xlabel('Client Index')
plt.ylabel('Learning Accuracy')
plt.legend(loc='upper left')
plt.title('Learning performance on Fashion dataset')
plt.xticks([x + bar/2 for x in wis], [f'C{i+1}' for i in range(10)])
plt.ylim(.75, .95)
# Out:
# (0.75, 0.95)

# %%
cifar_all = [acc[-1]*100 for acc in torch.load('CIFAR-VGG_11-Train2-All.acc')]
cifar_all.insert(0, 0), cifar_all.insert(4, 0)
cifar_all_15 = [acc[-1]*100 for acc in torch.load('CIFAR-VGG_11-Train2-All-15.acc')]
c_0, c_4 = cifar_all_15[8], cifar_all_15[9]
cifar_all_15 = cifar_all_15[:8]
cifar_all_15.insert(0, c_0), cifar_all_15.insert(4, c_4)
cifar_new_15 = [acc[-1]*100 for acc in torch.load('CIFAR-VGG_11-Train2-New-15.acc')]
c_0, c_4 = cifar_new_15[8], cifar_new_15[9]
cifar_new_15 = cifar_new_15[:8]
cifar_new_15.insert(0, c_0), cifar_new_15.insert(4, c_4)
bar = 0.3
prv = np.arange(len(cifar_all))
all = [x + bar for x in prv]
new = [x + bar for x in all]
plt.bar(prv, cifar_all, bar, label='1st train (w/o C1,C5)', color='g')
#plt.bar(all, cifar_all_15, bar, label='2nd train (w C1-C10)')
plt.plot(cifar_all_15, label='2nd train (w C1-C10)')
plt.scatter(prv, cifar_all_15)
#plt.bar(new, cifar_new_15, bar, label='2nd train (w C1,C5)')
plt.plot(cifar_new_15, label='2nd train (w C1,C5)')
plt.scatter(prv, cifar_new_15)
plt.xlabel('Client Index')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
plt.title('Learning performance under imbalanced CIFAR10')
plt.xticks([x + bar/2 for x in wis], [f'C{i+1}' for i in range(10)])
plt.ylim(20, 90)
# Out:
# (20.0, 90.0)

# %%
cifar_all = [acc[-1]*100 for acc in torch.load('CIFAR-VGG_11-Train2-IID-All.acc')]
cifar_all.insert(0, 0), cifar_all.insert(4, 0)
cifar_all_15 = [acc[-1]*100 for acc in torch.load('CIFAR-VGG_11-Train2-IID-All-15.acc')]
c_0, c_4 = cifar_all_15[8], cifar_all_15[9]
cifar_all_15 = cifar_all_15[:8]
cifar_all_15.insert(0, c_0), cifar_all_15.insert(4, c_4)
cifar_new_15 = [acc[-1]*100 for acc in torch.load('CIFAR-VGG_11-Train2-IID-New-15.acc')]
c_0, c_4 = cifar_new_15[8], cifar_new_15[9]
cifar_new_15 = cifar_new_15[:8]
cifar_new_15.insert(0, c_0), cifar_new_15.insert(4, c_4)
bar = 0.3
prv = np.arange(len(cifar_all))
all = [x + bar for x in prv]
new = [x + bar for x in all]
plt.bar(prv, cifar_all, bar, label='1st train (w/o C1,C5)', color='g')
#plt.bar(all, cifar_all_15, bar, label='2nd train (w C1-C10)')
plt.plot(cifar_all_15, label='2nd train (w C1-C10)')
plt.scatter(prv, cifar_all_15)
#plt.bar(new, cifar_new_15, bar, label='2nd train (w C1,C5)')
plt.plot(cifar_new_15, label='2nd train (w C1,C5)')
plt.scatter(prv, cifar_new_15)
plt.xlabel('Client Index')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
plt.title('Learning performance under balanced CIFAR10')
plt.xticks([x + bar/2 for x in wis], [f'C{i+1}' for i in range(10)])
plt.ylim(2, 90)
# Out:
# (2.0, 90.0)

# %%
fashion_prv = [[a*100 for a in acc] for acc in torch.load('Fashion-VGG_7-Train1-IID-Prv.acc')]
for i, acc in enumerate(fashion_prv):
  plt.plot(acc, label='C{}: {:.1%}'.format(i+1, acc[-1]/100))
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
plt.title('Learning performance under balanced Fashion')
plt.ylim(60, 94)
# Out:
# (60.0, 94.0)

# %%
fashion_prv = [[a*100 for a in acc] for acc in torch.load('Fashion-VGG_7-Train1-Prv.acc')]
for i, acc in enumerate(fashion_prv):
  plt.plot(acc, label='C{}: {:.1%}'.format(i+1, acc[-1]/100))
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
plt.title('Learning performance under imbalanced Fashion')
plt.ylim(60, 94)
# Out:
# (60.0, 94.0)

# %%
fashion_cac = [[a*100 for a in acc] for acc in torch.load('Fashion-VGG_7-Train1-Cac.acc')]
for i, acc in enumerate(fashion_cac):
  plt.plot(acc, label='C{}: {:.1%}'.format(i+1, acc[-1]/100))
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
plt.title('Learning performance under imbalanced Fashion')
plt.ylim(60, 94)
# Out:
# (60.0, 94.0)

# %%
fashion_cac = [[a*100 for a in acc] for acc in torch.load('Fashion-VGG_7-Train1-IID-C08.acc')]
for i, acc in enumerate(fashion_cac):
  plt.plot(acc, label='C{}: {:.1%}'.format(i+1, acc[-1]/100))
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
plt.title('Learning performance under balanced Fashion')
plt.ylim(60, 94)
# Out:
# (60.0, 94.0)

# %%
cifar_prv = [[a*100 for a in acc] for acc in torch.load('CIFAR-VGG_11-Train1-IID-Prv.acc')]
for i, acc in enumerate(cifar_prv):
  plt.plot(acc, label='C{}: {:.1%}'.format(i+1, acc[-1]/100))
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
plt.title('Learning performance under balanced CIFAR10')
plt.ylim(10, 80)
np.mean([acc[-1] for acc in cifar_prv])
# Out:
# 70.929

# %%
cifar_prv = [[a*100 for a in acc] for acc in torch.load('CIFAR-VGG_11-Train1-Prv.acc')]
for i, acc in enumerate(cifar_prv):
  plt.plot(acc, label='C{}: {:.1%}'.format(i+1, acc[-1]/100))
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
plt.title('Learning performance under imbalanced CIFAR10')
plt.ylim(10, 80)
# Out:
# (10.0, 80.0)

# %%
cifar_cac = [[a*100 for a in acc] for acc in torch.load('CIFAR-VGG_11-Train1-Cac.acc')]
for i, acc in enumerate(cifar_cac):
  plt.plot(acc, label='C{}: {:.1%}'.format(i+1, acc[-1]/100))
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
plt.title('Learning performance under imbalanced CIFAR10')
plt.ylim(10, 80)
# Out:
# (10.0, 80.0)

# %%
cifar_cac = [[a*100 for a in acc] for acc in torch.load('CIFAR-VGG_11-Train1-IID-C04.acc')]
for i, acc in enumerate(cifar_cac):
  plt.plot(acc, label='C{}: {:.1%}'.format(i+1, acc[-1]/100))
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
plt.title('Learning performance under balanced CIFAR10')
plt.ylim(10, 80)
np.mean([acc[-1] for acc in cifar_cac])
# Out:
# 73.876

# %%
fashion_all = [acc for acc in torch.load('Fashion-VGG_7-Train2-All.acc')]
fashion_all.insert(0, []), fashion_all.insert(4, [])
for i, acc in enumerate(fashion_all):
  if (len(acc) == 0): continue
  plt.plot(acc, label='C{}:{:.1%}'.format(i+1, acc[-1]))
plt.xlabel('Client Index')
plt.ylabel('Learning Accuracy')
plt.legend(loc='lower right')
plt.title('Learning performance on Fashion dataset')
plt.ylim(0.2, .95)
# Out:
# (0.2, 0.95)

# %%
fashion_all = [acc for acc in torch.load('Fashion-VGG_7-Train2-All-15.acc')]
fashion_all.insert(0, []), fashion_all.insert(4, [])
for i, acc in enumerate(fashion_all[:-2]):
  if (len(acc) == 0): continue
  plt.plot(acc, label='C{}:{:.1%}'.format(i+1, acc[-1]))
plt.plot(fashion_all[-2], label='C1:{:.1%}(new)'.format(fashion_all[-2][-1]))
plt.plot(fashion_all[-1], label='C5:{:.1%}(new)'.format(fashion_all[-1][-1]))
plt.xlabel('Client Index')
plt.ylabel('Learning Accuracy')
plt.legend(loc='lower right')
plt.title('Learning performance on Fashion dataset')
plt.ylim(0.2, .95)
# Out:
# (0.2, 0.95)

# %%
fashion_cac = [acc for acc in torch.load('Fashion-VGG_7-Train2-Cac-New-15.acc')]
fashion_cac.insert(0, []), fashion_cac.insert(4, [])
for i, acc in enumerate(fashion_cac[:-2]):
  if (len(acc) == 0): continue
  plt.plot(acc, label='C{}:{:.1%}'.format(i+1, acc[-1]))
plt.plot(fashion_cac[-2], label='C1:{:.1%}(new)'.format(fashion_cac[-2][-1]))
plt.plot(fashion_cac[-1], label='C5:{:.1%}(new)'.format(fashion_cac[-1][-1]))
plt.xlabel('Client Index')
plt.ylabel('Learning Accuracy')
plt.legend(loc='lower right')
plt.title('Learning performance on Fashion dataset')
plt.ylim(0.2, .95)
# Out:
# (0.2, 0.95)

# %%
fashion_new = [[a*100 for a in acc] for acc in torch.load('Fashion-VGG_7-Train2-IID-New-15.acc')]
fashion_new.insert(0, []), fashion_new.insert(4, [])
for i, acc in enumerate(fashion_new[:-2]):
  if (len(acc) == 0): continue
  plt.plot(acc, label='C{}: {:.1%}'.format(i+1, acc[-1]/100))
plt.plot(fashion_new[-2], label='C1: {:.1%}(new)'.format(fashion_new[-2][-1]/100))
plt.plot(fashion_new[-1], label='C5: {:.1%}(new)'.format(fashion_new[-1][-1]/100))
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
plt.title('Learning performance under balanced Fashion')
plt.ylim(10, 94)
# Out:
# (10.0, 94.0)

# %%
fashion_new = [[a*100 for a in acc] for acc in torch.load('Fashion-VGG_7-Train2-New-15.acc')]
fashion_new.insert(0, []), fashion_new.insert(4, [])
for i, acc in enumerate(fashion_new[:-2]):
  if (len(acc) == 0): continue
  plt.plot(acc, label='C{}: {:.1%}'.format(i+1, acc[-1]/100))
plt.plot(fashion_new[-2], label='C1: {:.1%}(new)'.format(fashion_new[-2][-1]/100))
plt.plot(fashion_new[-1], label='C5: {:.1%}(new)'.format(fashion_new[-1][-1]/100))
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
plt.title('Learning performance under imbalanced Fashion')
plt.ylim(10, 94)
# Out:
# (10.0, 94.0)

# %%
fashion_cac = [[a*100 for a in acc] for acc in torch.load('Fashion-VGG_7-Train2-Cac-New-15.acc')]
fashion_cac.insert(0, []), fashion_cac.insert(4, [])
for i, acc in enumerate(fashion_cac[:-2]):
  if (len(acc) == 0): continue
  plt.plot(acc, label='C{}: {:.1%}'.format(i+1, acc[-1]/100))
plt.plot(fashion_cac[-2], label='C1: {:.1%}(new)'.format(fashion_cac[-2][-1]/100))
plt.plot(fashion_cac[-1], label='C5: {:.1%}(new)'.format(fashion_cac[-1][-1]/100))
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
plt.title('Learning performance under imbalanced Fashion')
plt.ylim(10, 94)
# Out:
# (10.0, 94.0)

# %%
fashion_cac = [[a*100 for a in acc] for acc in torch.load('Fashion-VGG_7-Train2-IID-Cac-New-15.acc')]
fashion_cac.insert(0, []), fashion_cac.insert(4, [])
for i, acc in enumerate(fashion_cac[:-2]):
  if (len(acc) == 0): continue
  plt.plot(acc, label='C{}: {:.1%}'.format(i+1, acc[-1]/100))
plt.plot(fashion_cac[-2], label='C1:{:.1%}(new)'.format(fashion_cac[-2][-1]/100))
plt.plot(fashion_cac[-1], label='C5:{:.1%}(new)'.format(fashion_cac[-1][-1]/100))
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
plt.title('Learning performance under balanced Fashion')
plt.ylim(10, 94)
# Out:
# (10.0, 94.0)

# %%
cifar_new = [[a*100 for a in acc] for acc in torch.load('CIFAR-VGG_11-Train2-IID-New-15.acc')]
cifar_new.insert(0, []), cifar_new.insert(4, [])
for i, acc in enumerate(cifar_new[:-2]):
  if (len(acc) == 0): continue
  plt.plot(acc, label='C{}: {:.1%}'.format(i+1, acc[-1]/100))
plt.plot(cifar_new[-2], label='C1: {:.1%}(new)'.format(cifar_new[-2][-1]/100))
plt.plot(cifar_new[-1], label='C5: {:.1%}(new)'.format(cifar_new[-1][-1]/100))
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower center')
plt.title('Learning performance under balanced CIFAR10')
plt.ylim(10, 74)
# Out:
# (10.0, 74.0)

# %%
cifar_new = [[a*100 for a in acc] for acc in torch.load('CIFAR-VGG_11-Train2-New-15.acc')]
cifar_new.insert(0, []), cifar_new.insert(4, [])
for i, acc in enumerate(cifar_new[:-2]):
  if (len(acc) == 0): continue
  plt.plot(acc, label='C{}: {:.1%}'.format(i+1, acc[-1]/100))
plt.plot(cifar_new[-2], label='C1: {:.1%}(new)'.format(cifar_new[-2][-1]/100))
plt.plot(cifar_new[-1], label='C5: {:.1%}(new)'.format(cifar_new[-1][-1]/100))
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower center')
plt.title('Learning performance under imbalanced CIFAR10')
plt.ylim(10, 74)
# Out:
# (10.0, 74.0)

# %%
cifar_cac = [[a*100 for a in acc] for acc in torch.load('CIFAR-VGG_11-Train2-Cac-New-15.acc')]
cifar_cac.insert(0, []), cifar_cac.insert(4, [])
for i, acc in enumerate(cifar_cac[:-2]):
  if (len(acc) == 0): continue
  plt.plot(acc, label='C{}: {:.1%}'.format(i+1, acc[-1]/100))
plt.plot(cifar_cac[-2], label='C1: {:.1%}(new)'.format(cifar_cac[-2][-1]/100))
plt.plot(cifar_cac[-1], label='C5: {:.1%}(new)'.format(cifar_cac[-1][-1]/100))
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower center')
plt.title('Learning performance under imbalanced CIFAR10')
plt.ylim(10, 74)
# Out:
# (10.0, 74.0)

# %%
cifar_cac = [[a*100 for a in acc] for acc in torch.load('CIFAR-VGG_11-Train2-IID-Cac-New-15.acc')]
cifar_cac.insert(0, []), cifar_cac.insert(4, [])
for i, acc in enumerate(cifar_cac[:-2]):
  if (len(acc) == 0): continue
  plt.plot(acc, label='C{}: {:.1%}'.format(i+1, acc[-1]/100))
plt.plot(cifar_cac[-2], label='C1: {:.1%}(new)'.format(cifar_cac[-2][-1]/100))
plt.plot(cifar_cac[-1], label='C5: {:.1%}(new)'.format(cifar_cac[-1][-1]/100))
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower center')
plt.title('Learning performance under balanced CIFAR10')
plt.ylim(10, 74)
# Out:
# (10.0, 74.0)
